# %% [markdown]
# **GStore Dataset Revenue Prediction**
#
# About the dataset:
#
# Each row in the dataset is one visit to the store. We are predicting the natural log(In) of the sum of all transactions per user.
#
# **fullVisitorId**- A unique identifier for each user of the Google Merchandise Store.
# **channelGrouping** - The channel via which the user came to the Store.
# **date** - The date on which the user visited the Store.
# **device** - The specifications for the device used to access the Store.
# **geoNetwork** - This section contains information about the geography of the user.
# **sessionId** - A unique identifier for this visit to the store.
# **socialEngagementType** - Engagement type, either "Socially Engaged" or "Not Socially Engaged".
# **totals** - This section contains aggregate values across the session.
# **trafficSource** - This section contains information about the Traffic Source from which the session originated.
# **visitId** - An identifier for this session. This is part of the value usually stored as the _utmb cookie. This is only unique to the user. For a completely unique ID, you should use a combination of fullVisitorId and visitId.
# **visitNumber** - The session number for this user. If this is the first session, then this is set to 1.
# **visitStartTime** - The timestamp (expressed as POSIX time).
#
# Also it is important to note that some of the fields are in json format.
#
#  As generally used in many other competitions, we can convert all the json fields in the file to a  csv format. Thanks  Julian for the excellent kernel.

# %%
import numpy as np
import pandas as pd
import json
import os
from pandas.io.json import json_normalize
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('train_v2.csv', skiprows=600000, nrows=600000)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.shape
# Out:
# (600000, 13)

# %%
org = pd.read_csv('train_v2.csv', nrows=2)

# %%
org.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral  [{'index': '4', 'value': 'North America'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
#
#                                           geoNetwork  \
# 0  {"continent": "Europe", "subContinent": "Weste...
# 1  {"continent": "Americas", "subContinent": "Nor...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  {"visits": "1", "hits": "2", "pageviews": "2",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1508198450            1
# 1  {"referralPath": "/a/google.com/transportation...  1508176307            6
#
#    visitStartTime
# 0      1508198450
# 1      1508176307

# %%
data.columns = org.columns

# %%
data.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0        Referral                                          []  20171023
# 1      Affiliates  [{'index': '4', 'value': 'North America'}]  20171023
# 2        Referral           [{'index': '4', 'value': 'EMEA'}]  20171023
# 3  Organic Search  [{'index': '4', 'value': 'North America'}]  20171023
# 4          Direct  [{'index': '4', 'value': 'North America'}]  20171023
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  1779918779114274637
# 1  {"browser": "Chrome", "browserVersion": "not a...  1283351000208574720
# 2  {"browser": "Safari", "browserVersion": "not a...  6671401837297695888
# 3  {"browser": "Chrome", "browserVersion": "not a...  4625051014705510930
# 4  {"browser": "Chrome", "browserVersion": "not a...  9189836233641716254
#
#                                           geoNetwork  \
# 0  {"continent": "Europe", "subContinent": "South...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Europe", "subContinent": "Weste...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '8', ...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '5', ...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "2", "pageviews": "2",...
# 1  {"visits": "1", "hits": "2", "pageviews": "2",...
# 2  {"visits": "1", "hits": "2", "pageviews": "2",...
# 3  {"visits": "1", "hits": "2", "pageviews": "2",...
# 4  {"visits": "1", "hits": "2", "pageviews": "1",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"referralPath": "/blog/2016/08/03/google-anal...  1508774082            1
# 1  {"campaign": "Data Share Promo", "source": "Pa...  1508782750            1
# 2  {"referralPath": "/analytics/web/", "campaign"...  1508763066            4
# 3  {"campaign": "(not set)", "source": "google", ...  1508766659            3
# 4  {"campaign": "(not set)", "source": "(direct)"...  1508784362            1
#
#    visitStartTime
# 0      1508774082
# 1      1508782750
# 2      1508763066
# 3      1508766659
# 4      1508784362

# %%
data.to_csv('train2.csv', index=False)

# %%
data.dtypes
# Out:
# channelGrouping         object
# customDimensions        object
# date                     int64
# device                  object
# fullVisitorId           object
# geoNetwork              object
# hits                    object
# socialEngagementType    object
# totals                  object
# trafficSource           object
# visitId                  int64
# visitNumber              int64
# visitStartTime           int64
# dtype: object

# %%
def load_df(csv_path='train2.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
# %%time
train_df = load_df()
# Out:
# Loaded train2.csv. Shape: (600000, 59)
# CPU times: user 2min 41s, sys: 26.2 s, total: 3min 7s
# Wall time: 3min 15s

# %%
train_df.head(2)
# Out:
#   channelGrouping                            customDimensions      date  \
# 0        Referral                                          []  20171023
# 1      Affiliates  [{'index': '4', 'value': 'North America'}]  20171023
#
#          fullVisitorId                                               hits  \
# 0  1779918779114274637  [{'hitNumber': '1', 'time': '0', 'hour': '8', ...
# 1  1283351000208574720  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1508774082            1      1508774082
# 1  Not Socially Engaged  1508782750            1      1508782750
#
#   device.browser         ...          trafficSource.adwordsClickInfo.gclId  \
# 0         Chrome         ...                                           NaN
# 1         Chrome         ...                                           NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
#
#    trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0               (not set)                        NaN                   NaN
# 1        Data Share Promo                        NaN                   NaN
#
#   trafficSource.medium                       trafficSource.referralPath  \
# 0             referral  /blog/2016/08/03/google-analytics-demo-account/
# 1            affiliate                                              NaN
#
#   trafficSource.source
# 0      lunametrics.com
# 1             Partners
#
# [2 rows x 59 columns]

# %%
column = 'customDimensions'
train_df[column] = train_df[column].apply(lambda x: eval(x)[0]['value'] if len(eval(x)) !=0 else np.nan)

# %%
train_df.head(2)
# Out:
#   channelGrouping customDimensions      date        fullVisitorId  \
# 0        Referral              NaN  20171023  1779918779114274637
# 1      Affiliates    North America  20171023  1283351000208574720
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '8', ...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
#
#       visitId  visitNumber  visitStartTime device.browser  \
# 0  1508774082            1      1508774082         Chrome
# 1  1508782750            1      1508782750         Chrome
#
#           ...          trafficSource.adwordsClickInfo.gclId  \
# 0         ...                                           NaN
# 1         ...                                           NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
#
#    trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0               (not set)                        NaN                   NaN
# 1        Data Share Promo                        NaN                   NaN
#
#   trafficSource.medium                       trafficSource.referralPath  \
# 0             referral  /blog/2016/08/03/google-analytics-demo-account/
# 1            affiliate                                              NaN
#
#   trafficSource.source
# 0      lunametrics.com
# 1             Partners
#
# [2 rows x 59 columns]

# %%
column = 'hits'
train_df[column] = train_df[column].apply(lambda x: eval(x)[0] if len(eval(x)) !=0 else np.nan)

# %%
train_df.to_csv('GStoreData_EDA-Part2son.csv')

# %%
train_df['hits'] = train_df['hits'].fillna('null')

# %%
# na_index = train_df[train_df.hits == 'null'].index
# train_df.hits = train_df.hits.replace('null',"{'null':'null'}")
train_df.loc[na_index,'hits'] = train_df.loc[na_index,'hits'].apply(lambda x: eval(x))

# %%
column_as_df = json_normalize(train_df[column])
column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
train_df = train_df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)

# %%
pd.set_option('display.max_columns', 200)
train_df.head()
# Out:
#   channelGrouping customDimensions      date        fullVisitorId  \
# 0        Referral              NaN  20171023  1779918779114274637
# 1      Affiliates    North America  20171023  1283351000208574720
# 2        Referral             EMEA  20171023  6671401837297695888
# 3  Organic Search    North America  20171023  4625051014705510930
# 4          Direct    North America  20171023  9189836233641716254
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1508774082            1      1508774082
# 1  Not Socially Engaged  1508782750            1      1508782750
# 2  Not Socially Engaged  1508763066            4      1508763066
# 3  Not Socially Engaged  1508766659            3      1508766659
# 4  Not Socially Engaged  1508784362            1      1508784362
#
#   device.browser             device.browserSize  \
# 0         Chrome  not available in demo dataset
# 1         Chrome  not available in demo dataset
# 2         Safari  not available in demo dataset
# 3         Chrome  not available in demo dataset
# 4         Chrome  not available in demo dataset
#
#            device.browserVersion device.deviceCategory  \
# 0  not available in demo dataset               desktop
# 1  not available in demo dataset               desktop
# 2  not available in demo dataset               desktop
# 3  not available in demo dataset               desktop
# 4  not available in demo dataset               desktop
#
#              device.flashVersion  device.isMobile  \
# 0  not available in demo dataset            False
# 1  not available in demo dataset            False
# 2  not available in demo dataset            False
# 3  not available in demo dataset            False
# 4  not available in demo dataset            False
#
#                  device.language    device.mobileDeviceBranding  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device.mobileDeviceInfo device.mobileDeviceMarketingName  \
# 0  not available in demo dataset    not available in demo dataset
# 1  not available in demo dataset    not available in demo dataset
# 2  not available in demo dataset    not available in demo dataset
# 3  not available in demo dataset    not available in demo dataset
# 4  not available in demo dataset    not available in demo dataset
#
#         device.mobileDeviceModel     device.mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device.operatingSystem  device.operatingSystemVersion  \
# 0                Windows  not available in demo dataset
# 1                Windows  not available in demo dataset
# 2              Macintosh  not available in demo dataset
# 3              Macintosh  not available in demo dataset
# 4                Windows  not available in demo dataset
#
#              device.screenColors        device.screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  geoNetwork.city              geoNetwork.cityId  \
# 0  not available in demo dataset  not available in demo dataset
# 1                      Wellesley  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   geoNetwork.continent geoNetwork.country            geoNetwork.latitude  \
# 0               Europe           Portugal  not available in demo dataset
# 1             Americas      United States  not available in demo dataset
# 2               Europe            Germany  not available in demo dataset
# 3             Americas      United States  not available in demo dataset
# 4             Americas      United States  not available in demo dataset
#
#             geoNetwork.longitude               geoNetwork.metro  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset        Boston MA-Manchester NH
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   geoNetwork.networkDomain     geoNetwork.networkLocation  \
# 0              vodafone.pt  not available in demo dataset
# 1          unknown.unknown  not available in demo dataset
# 2          unknown.unknown  not available in demo dataset
# 3              comcast.net  not available in demo dataset
# 4              verizon.net  not available in demo dataset
#
#                geoNetwork.region geoNetwork.subContinent totals.bounces  \
# 0  not available in demo dataset         Southern Europe            NaN
# 1                  Massachusetts        Northern America            NaN
# 2  not available in demo dataset          Western Europe            NaN
# 3  not available in demo dataset        Northern America            NaN
# 4  not available in demo dataset        Northern America            NaN
#
#   totals.hits totals.newVisits totals.pageviews totals.sessionQualityDim  \
# 0           2                1                2                        1
# 1           2                1                2                        1
# 2           2              NaN                2                        1
# 3           2              NaN                2                        3
# 4           2                1                1                        1
#
#   totals.timeOnSite totals.totalTransactionRevenue totals.transactionRevenue  \
# 0                33                            NaN                       NaN
# 1               236                            NaN                       NaN
# 2                 8                            NaN                       NaN
# 3                 9                            NaN                       NaN
# 4                11                            NaN                       NaN
#
#   totals.transactions totals.visits trafficSource.adContent  \
# 0                 NaN             1                     NaN
# 1                 NaN             1                     NaN
# 2                 NaN             1                     NaN
# 3                 NaN             1                     NaN
# 4                 NaN             1                     NaN
#
#   trafficSource.adwordsClickInfo.adNetworkType  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   trafficSource.adwordsClickInfo.criteriaParameters  \
# 0                     not available in demo dataset
# 1                     not available in demo dataset
# 2                     not available in demo dataset
# 3                     not available in demo dataset
# 4                     not available in demo dataset
#
#   trafficSource.adwordsClickInfo.gclId  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0              (not set)                        NaN                   NaN
# 1       Data Share Promo                        NaN                   NaN
# 2              (not set)                       True                   NaN
# 3              (not set)                       True        (not provided)
# 4              (not set)                       True                   NaN
#
#   trafficSource.medium                       trafficSource.referralPath  \
# 0             referral  /blog/2016/08/03/google-analytics-demo-account/
# 1            affiliate                                              NaN
# 2             referral                                  /analytics/web/
# 3              organic                                              NaN
# 4               (none)                                              NaN
#
#    trafficSource.source                  hits.appInfo.exitScreenName  \
# 0       lunametrics.com         shop.googlemerchandisestore.com/home
# 1              Partners         shop.googlemerchandisestore.com/home
# 2  analytics.google.com  shop.googlemerchandisestore.com/basket.html
# 3                google   shop.googlemerchandisestore.com/store.html
# 4              (direct)  shop.googlemerchandisestore.com/basket.html
#
#                 hits.appInfo.landingScreenName hits.appInfo.screenDepth  \
# 0         shop.googlemerchandisestore.com/home                        0
# 1         shop.googlemerchandisestore.com/home                        0
# 2  shop.googlemerchandisestore.com/basket.html                        0
# 3  shop.googlemerchandisestore.com/basket.html                        0
# 4  shop.googlemerchandisestore.com/basket.html                        0
#
#                        hits.appInfo.screenName  \
# 0         shop.googlemerchandisestore.com/home
# 1         shop.googlemerchandisestore.com/home
# 2  shop.googlemerchandisestore.com/basket.html
# 3  shop.googlemerchandisestore.com/basket.html
# 4  shop.googlemerchandisestore.com/basket.html
#
#   hits.contentGroup.contentGroup1 hits.contentGroup.contentGroup2  \
# 0                       (not set)                       (not set)
# 1                       (not set)                       (not set)
# 2                       (not set)                       (not set)
# 3                       (not set)                       (not set)
# 4                       (not set)                       (not set)
#
#   hits.contentGroup.contentGroup3 hits.contentGroup.contentGroup4  \
# 0                       (not set)                       (not set)
# 1                       (not set)                       (not set)
# 2                       (not set)                       (not set)
# 3                       (not set)                       (not set)
# 4                       (not set)                       (not set)
#
#   hits.contentGroup.contentGroup5 hits.contentGroup.contentGroupUniqueViews1  \
# 0                       (not set)                                        NaN
# 1                       (not set)                                        NaN
# 2                       (not set)                                        NaN
# 3                       (not set)                                        NaN
# 4                       (not set)                                        NaN
#
#   hits.contentGroup.contentGroupUniqueViews2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   hits.contentGroup.contentGroupUniqueViews3  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   hits.contentGroup.previousContentGroup1  \
# 0                              (entrance)
# 1                              (entrance)
# 2                              (entrance)
# 3                              (entrance)
# 4                              (entrance)
#
#   hits.contentGroup.previousContentGroup2  \
# 0                              (entrance)
# 1                              (entrance)
# 2                              (entrance)
# 3                              (entrance)
# 4                              (entrance)
#
#   hits.contentGroup.previousContentGroup3  \
# 0                              (entrance)
# 1                              (entrance)
# 2                              (entrance)
# 3                              (entrance)
# 4                              (entrance)
#
#   hits.contentGroup.previousContentGroup4  \
# 0                              (entrance)
# 1                              (entrance)
# 2                              (entrance)
# 3                              (entrance)
# 4                              (entrance)
#
#   hits.contentGroup.previousContentGroup5 hits.customDimensions  \
# 0                              (entrance)                    []
# 1                              (entrance)                    []
# 2                              (entrance)                    []
# 3                              (entrance)                    []
# 4                              (entrance)                    []
#
#   hits.customMetrics hits.customVariables hits.dataSource  \
# 0                 []                   []             web
# 1                 []                   []             web
# 2                 []                   []             web
# 3                 []                   []             web
# 4                 []                   []             web
#
#   hits.eCommerceAction.action_type hits.eCommerceAction.option  \
# 0                                0                         NaN
# 1                                0                         NaN
# 2                                0                         NaN
# 3                                0                         NaN
# 4                                0                         NaN
#
#   hits.eCommerceAction.step hits.eventInfo.eventAction  \
# 0                         1                        NaN
# 1                         1                        NaN
# 2                         1                        NaN
# 3                         1                        NaN
# 4                         1                        NaN
#
#   hits.eventInfo.eventCategory hits.eventInfo.eventLabel  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
#
#   hits.exceptionInfo.isFatal hits.experiment hits.hitNumber hits.hour  \
# 0                       True              []              1         8
# 1                       True              []              1        11
# 2                       True              []              1         5
# 3                       True              []              1         6
# 4                       True              []              1        11
#
#   hits.isEntrance hits.isExit hits.isInteraction hits.item.currencyCode  \
# 0            True         NaN               True                    NaN
# 1            True         NaN               True                    NaN
# 2            True         NaN               True                    NaN
# 3            True         NaN               True                    NaN
# 4            True        True               True                    NaN
#
#   hits.item.transactionId hits.latencyTracking.domContentLoadedTime  \
# 0                     NaN                                       NaN
# 1                     NaN                                       NaN
# 2                     NaN                                       NaN
# 3                     NaN                                       NaN
# 4                     NaN                                       NaN
#
#   hits.latencyTracking.domInteractiveTime  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   hits.latencyTracking.domLatencyMetricsSample  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   hits.latencyTracking.domainLookupTime hits.latencyTracking.pageDownloadTime  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#   hits.latencyTracking.pageLoadSample hits.latencyTracking.pageLoadTime  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
#
#   hits.latencyTracking.redirectionTime  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   hits.latencyTracking.serverConnectionTime  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   hits.latencyTracking.serverResponseTime  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   hits.latencyTracking.speedMetricsSample hits.minute hits.null  \
# 0                                     NaN          54       NaN
# 1                                     NaN          19       NaN
# 2                                     NaN          51       NaN
# 3                                     NaN          50       NaN
# 4                                     NaN          46       NaN
#
#                 hits.page.hostname hits.page.pagePath  \
# 0  shop.googlemerchandisestore.com              /home
# 1  shop.googlemerchandisestore.com              /home
# 2  shop.googlemerchandisestore.com       /basket.html
# 3  shop.googlemerchandisestore.com       /basket.html
# 4  shop.googlemerchandisestore.com       /basket.html
#
#   hits.page.pagePathLevel1 hits.page.pagePathLevel2 hits.page.pagePathLevel3  \
# 0                    /home
# 1                    /home
# 2             /basket.html
# 3             /basket.html
# 4             /basket.html
#
#   hits.page.pagePathLevel4 hits.page.pageTitle hits.page.searchCategory  \
# 0                                         Home                      NaN
# 1                                         Home                      NaN
# 2                                Shopping Cart                      NaN
# 3                                Shopping Cart                      NaN
# 4                                Shopping Cart                      NaN
#
#   hits.page.searchKeyword hits.product  \
# 0                     NaN           []
# 1                     NaN           []
# 2                     NaN           []
# 3                     NaN           []
# 4                     NaN           []
#
#                                       hits.promotion  \
# 0  [{'promoId': 'Apparel Row 1', 'promoName': 'Ap...
# 1  [{'promoId': 'Apparel Row 1', 'promoName': 'Ap...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#   hits.promotionActionInfo.promoIsClick hits.promotionActionInfo.promoIsView  \
# 0                                   NaN                                 True
# 1                                   NaN                                 True
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   hits.publisher_infos                                       hits.referer  \
# 0                   []  https://www.lunametrics.com/blog/2016/08/03/go...
# 1                   []  https://support.google.com/analytics/answer/63...
# 2                   []        https://analytics.google.com/analytics/web/
# 3                   []                                                NaN
# 4                   []                                                NaN
#
#   hits.social.hasSocialSourceReferral  \
# 0                                  No
# 1                                  No
# 2                                  No
# 3                                  No
# 4                                  No
#
#   hits.social.socialInteractionNetworkAction hits.social.socialNetwork  \
# 0                                         :                  (not set)
# 1                                         :                  (not set)
# 2                                         :                  (not set)
# 3                                         :                  (not set)
# 4                                         :                  (not set)
#
#   hits.time hits.transaction.affiliation hits.transaction.currencyCode  \
# 0         0                          NaN                           NaN
# 1         0                          NaN                           NaN
# 2         0                          NaN                           NaN
# 3         0                          NaN                           NaN
# 4         0                          NaN                           NaN
#
#   hits.transaction.localTransactionRevenue  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   hits.transaction.localTransactionShipping  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   hits.transaction.localTransactionTax hits.transaction.transactionId  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#   hits.transaction.transactionRevenue hits.transaction.transactionShipping  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hits.transaction.transactionTax hits.type
# 0                             NaN      PAGE
# 1                             NaN      PAGE
# 2                             NaN      PAGE
# 3                             NaN      PAGE
# 4                             NaN      PAGE

# %%
train_df.isnull().sum()
# Out:
# channelGrouping                                    0
# customDimensions                              117546
# date                                               0
# fullVisitorId                                      0
# socialEngagementType                               0
# visitId                                            0
# visitNumber                                        0
# visitStartTime                                     0
# device.browser                                     0
# device.browserSize                                 0
# device.browserVersion                              0
# device.deviceCategory                              0
# device.flashVersion                                0
# device.isMobile                                    0
# device.language                                    0
# device.mobileDeviceBranding                        0
# device.mobileDeviceInfo                            0
# device.mobileDeviceMarketingName                   0
# device.mobileDeviceModel                           0
# device.mobileInputSelector                         0
# device.operatingSystem                             0
# device.operatingSystemVersion                      0
# device.screenColors                                0
# device.screenResolution                            0
# geoNetwork.city                                    0
# geoNetwork.cityId                                  0
# geoNetwork.continent                               0
# geoNetwork.country                                 0
# geoNetwork.latitude                                0
# geoNetwork.longitude                               0
#                                                ...
# hits.null                                     599665
# hits.page.hostname                               335
# hits.page.pagePath                               335
# hits.page.pagePathLevel1                         335
# hits.page.pagePathLevel2                         335
# hits.page.pagePathLevel3                         335
# hits.page.pagePathLevel4                         335
# hits.page.pageTitle                              393
# hits.page.searchCategory                      599662
# hits.page.searchKeyword                       599662
# hits.product                                     335
# hits.promotion                                   335
# hits.promotionActionInfo.promoIsClick         599788
# hits.promotionActionInfo.promoIsView          434969
# hits.publisher_infos                             335
# hits.referer                                  158360
# hits.social.hasSocialSourceReferral              335
# hits.social.socialInteractionNetworkAction       335
# hits.social.socialNetwork                        335
# hits.time                                        335
# hits.transaction.affiliation                  599996
# hits.transaction.currencyCode                 421186
# hits.transaction.localTransactionRevenue      599996
# hits.transaction.localTransactionShipping     599996
# hits.transaction.localTransactionTax          599996
# hits.transaction.transactionId                599996
# hits.transaction.transactionRevenue           599996
# hits.transaction.transactionShipping          599996
# hits.transaction.transactionTax               599996
# hits.type                                        335
# Length: 136, dtype: int64

# %%
train_df.shape
# Out:
# (600000, 136)

# %%
train_df.to_csv('GStoreData_EDA-Part2son1.csv', index=False)

# %%
### Target Var.
train_df['totals.transactionRevenue'].count()
# Out:
# 99

# %%
train_df['fullVisitorId'].nunique()
# Out:
# 9210

# %%
train_df['totals.transactionRevenue'] = train_df['totals.transactionRevenue'].astype(float)
a = train_df.groupby('fullVisitorId')['totals.transactionRevenue'].describe().sort_values('mean', ascending=False)

# %%
a.head()
# Out:
#                      count          mean  std           min           25%  \
# fullVisitorId
# 7638336411447332495    1.0  1.077000e+09  NaN  1.077000e+09  1.077000e+09
# 309482894121265066     1.0  9.004300e+08  NaN  9.004300e+08  9.004300e+08
# 3152246617474456269    1.0  6.355000e+08  NaN  6.355000e+08  6.355000e+08
# 7168226225550508027    1.0  5.939100e+08  NaN  5.939100e+08  5.939100e+08
# 3244885836845029978    1.0  5.741500e+08  NaN  5.741500e+08  5.741500e+08
#
#                               50%           75%           max  Shopped
# fullVisitorId
# 7638336411447332495  1.077000e+09  1.077000e+09  1.077000e+09     True
# 309482894121265066   9.004300e+08  9.004300e+08  9.004300e+08     True
# 3152246617474456269  6.355000e+08  6.355000e+08  6.355000e+08     True
# 7168226225550508027  5.939100e+08  5.939100e+08  5.939100e+08     True
# 3244885836845029978  5.741500e+08  5.741500e+08  5.741500e+08     True

# %%
a['mean'].count()/a.shape[0]
# Out:
# 0.010640608034744842

# %%
a['Shopped'] = a['count'] > 0

# %%
ax = sns.countplot(x="Shopped", data=a)

# %%
cons = ((train_df.astype(str).nunique() == 1)[train_df.astype(str).nunique() == 1]).index.values

# %%
train_df.drop(labels=cons, axis=1, inplace=True)

# %%
train_df.shape # Got rid of the redundant empty columns to save from memory.
# Out:
# (10000, 77)

# %%
train_df['device.operatingSystem'].unique()
# Out:
# array(['Windows', 'Chrome OS', 'Android', 'Macintosh', 'iOS', 'Linux',
#        '(not set)', 'Windows Phone', 'Samsung', 'Tizen', 'BlackBerry',
#        'OS/2', 'Playstation Vita', 'Xbox', 'Nintendo Wii'], dtype=object)

# %%
plt.figure(figsize=(5, 7))
sns.countplot(y='device.operatingSystem', data=train_df[train_df['device.operatingSystem'].isin(['Windows', 'Chrome OS', 'Android', 'Macintosh', 'iOS', 'Linux',
       '(not set)'])])

# %%
train_df['device.browser'].unique()
# Out:
# array(['Firefox', 'Chrome', 'Safari', 'UC Browser', 'Internet Explorer',
#        'Edge', 'Samsung Internet', 'Android Webview', 'Safari (in-app)',
#        'Opera Mini', 'Opera', 'YaBrowser', 'Amazon Silk',
#        'Mozilla Compatible Agent', 'Puffin', 'Maxthon', 'BlackBerry',
#        'ADM', 'Coc Coc', 'MRCHROME', 'Android Browser',
#        'Playstation Vita Browser', 'Nintendo Browser'], dtype=object)

# %%
plt.figure(figsize=(5, 10))
sns.countplot(y='device.browser', data=train_df[train_df['device.browser'].isin(['Firefox', 'Chrome', 'Safari', 'Internet Explorer',
       'Edge', 'Samsung Internet', 'Android Webview', 'Safari (in-app)',
       'Opera Mini', 'Opera', 'Amazon Silk'])])

# %%
train_df['device.deviceCategory'].unique()
# Out:
# array(['desktop', 'mobile', 'tablet'], dtype=object)

# %%
sns.countplot(y='device.deviceCategory', data=train_df)
